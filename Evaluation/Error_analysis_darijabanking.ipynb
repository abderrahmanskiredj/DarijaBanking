# %%
# !pip install --quiet transformers evaluate datasets

# %%
# !huggingface-cli login --token
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
from collections import Counter

def compute_metrics(ground_truth, predictions):
    unique_labels = set(ground_truth + predictions)
    true_positives = Counter()
    false_positives = Counter()
    false_negatives = Counter()

    for true_label, predicted_label in zip(ground_truth, predictions):
        if true_label == predicted_label:
            true_positives[true_label] += 1
        else:
            false_positives[predicted_label] += 1
            false_negatives[true_label] += 1

    precision = {}
    recall = {}
    f1_score = {}

    for label in unique_labels:
        precision[label] = true_positives[label] / (true_positives[label] + false_positives[label]) if (true_positives[label] + false_positives[label]) else 0
        recall[label] = true_positives[label] / (true_positives[label] + false_negatives[label]) if (true_positives[label] + false_negatives[label]) else 0
        f1_score[label] = 2 * (precision[label] * recall[label]) / (precision[label] + recall[label]) if (precision[label] + recall[label]) else 0

    macro_precision = sum(precision.values()) / len(unique_labels)
    macro_recall = sum(recall.values()) / len(unique_labels)
    macro_f1_score = sum(f1_score.values()) / len(unique_labels)
    accuracy = sum(true_positives.values()) / len(ground_truth)

    return accuracy, macro_precision, macro_recall, macro_f1_score

# Example usage:
ground_truth = ['a', 'b', 'c', 'a', 'b', 'c', "d", "d"]
predictions = ['a', 'b', 'c', 'c', 'b', 'a', "e", "d"]
accuracy, precision, recall, f1_score = compute_metrics(ground_truth, predictions)
print(f"Accuracy: {accuracy}\nPrecision: {precision}\nRecall: {recall}\nF1 Score: {f1_score}")
# Out:
# Accuracy: 0.625
# Precision: 0.6
# Recall: 0.5
# F1 Score: 0.5333333333333333

# %%
import pandas as pd
df = pd.read_excel('test data annotated far from msa sept 2024 v2.xlsx')
ground_truths = df['intent'].tolist()
df['darija'] = df['darija'].astype(str)
ar = df['arabic'].tolist()
dar = df['darija'].tolist()

# %%
df["different from msa from 1 to 3"] = df["different from msa from 1 to 3"].astype(int)

# %%
score_of_differences_dar_msa = df["different from msa from 1 to 3"].tolist()

# %%
df
# Out:
#                                                 arabic  \
# 0                                         هذا رائع جدا
# 1                      كيف يمكنني أن أضع طابعة جلدية ؟
# 2     أيمكنني إلغاء أمر للحصول على شهادة إيداع جديدة ؟
# 3                        معاملات مشكوك فيها على حسابي.
# 4               تم تأجيل المباراة ، ماذا علي أن أفعل ؟
# ..                                                 ...
# 357    أيمكنني أن أسأل عميلا ما هي ساعات دعم العملاء ؟
# 358  كيف لي أن أعرف إن كانت سياسة التأمين الخاصة بي...
# 359  أريد تغيير المعلومات عن بروفايلي ، كيف يمكنني ...
# 360  أيمكنك على الأقل أن تحاول أن تعالج شواغلي بدلا...
# 361  لقد سرقت كل شيء مني. لا يمكنني استخدام التطبيق...
#
#                                                 darija  \
# 0                                           هادشي واعر
# 1                              كيفاش نصلح طابعة عالقة؟
# 2             واش نقدر نلغي طلبية لشهادة ايداع جديدة؟
# 3                               عمليات مشبوهة فحسابي.
# 4                          تأجل الماتش، شنو لازم ندير؟
# ..                                                 ...
# 357          تقدر تسول  الوكيل على ساعات دعم الزبائن؟
# 358                  كيفاش نعرف بلي تأميني مازال ساري؟
# 359   بغيت نعدل المعلومات فبروفيل ديالي، كيفاش نديرها؟
# 360  تقدر تحاول تواجه مشاكلي بلا ما تعطيني جوابات ج...
# 361  كل شيء سُرق مني. لا أستطيع استخدام التطبيق. ير...
#
#      different from msa from 1 to 3                     intent
# 0                                 3  general_positive_feedback
# 1                                 2                     oodoos
# 2                                 2               cancel_order
# 3                                 1           compromised_card
# 4                                 3                 get_refund
# ..                              ...                        ...
# 357                               2   contact_customer_service
# 358                               2                  insurance
# 359                               2               edit_account
# 360                               1  general_negative_feedback
# 361                               1       lost_or_stolen_phone
#
# [362 rows x 4 columns]

# %% [markdown]
# # Bert like model Finetuning

# %%
from transformers import pipeline
from tqdm import tqdm
model = pipeline('text-classification', model="AbderrahmanSkiredj1/BERTouch")
ar_classified = model(ar)
dar_classified = model(dar)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/2.03k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/541M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/751k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.77M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/695 [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.

# %%
intent_pred_ara = ar_classified
intent_pred_ara = [x['label'] for x in intent_pred_ara]
intent_pred_dar = dar_classified
intent_pred_dar = [x['label'] for x in intent_pred_dar]
acc_msa, prec_msa, rec_msa, f1_msa = compute_metrics(ground_truths, intent_pred_ara)
acc_dar, prec_dar, rec_dar, f1_dar = compute_metrics(ground_truths, intent_pred_dar)
print(acc_msa, prec_msa, rec_msa, f1_msa)
print(acc_dar, prec_dar, rec_dar, f1_dar)
# Out:
# 0.9585635359116023 0.9575797466422467 0.9550175518925519 0.9555177498683695
# 0.9806629834254144 0.9798349628312862 0.9786095848595849 0.9786949074595171

# %%
from sklearn.metrics import classification_report

# %%
report_ar = classification_report(ground_truths, intent_pred_ara, output_dict=True)
report_dar = classification_report(ground_truths, intent_pred_dar, output_dict=True)

# Convert dictionaries to DataFrames
df_ar = pd.DataFrame(report_ar).transpose()
df_dar = pd.DataFrame(report_dar).transpose()

# Remove the 'accuracy' row for sorting purposes
df_ar = df_ar.drop(['accuracy'])
df_dar = df_dar.drop(['accuracy'])

# Sort intents by F1-score
sorted_ar = df_ar.sort_values(by='f1-score', ascending=False)
sorted_dar = df_dar.sort_values(by='f1-score', ascending=False)

# %%
sorted_ar
# Out:
#                            precision    recall  f1-score  support
# create_account              1.000000  1.000000  1.000000     19.0
# delete_account              1.000000  1.000000  1.000000     19.0
# cancel_order                1.000000  1.000000  1.000000     15.0
# cancel_transfer             1.000000  1.000000  1.000000     13.0
# general_positive_feedback   1.000000  1.000000  1.000000     13.0
# change_order                1.000000  1.000000  1.000000     18.0
# insurance                   1.000000  1.000000  1.000000     13.0
# contact_customer_service    1.000000  1.000000  1.000000     19.0
# edit_account                1.000000  1.000000  1.000000     14.0
# get_refund                  1.000000  1.000000  1.000000     18.0
# get_invoice                 0.952381  1.000000  0.975610     20.0
# contact_human_agent         0.950000  1.000000  0.974359     19.0
# fee                         1.000000  0.923077  0.960000     13.0
# lost_or_stolen_phone        0.923077  1.000000  0.960000     12.0
# weighted avg                0.959663  0.958564  0.958390    362.0
# loan                        1.000000  0.916667  0.956522     12.0
# age_limit                   1.000000  0.916667  0.956522     12.0
# macro avg                   0.957580  0.955018  0.955518    362.0
# exchange                    0.933333  0.933333  0.933333     15.0
# card_swallowed              1.000000  0.875000  0.933333     16.0
# general_negative_feedback   0.928571  0.928571  0.928571     14.0
# deactivate_my_card          0.866667  1.000000  0.928571     13.0
# oodoos                      0.923077  0.923077  0.923077     13.0
# activate_my_card            0.923077  0.923077  0.923077     13.0
# compromised_card            0.812500  0.866667  0.838710     15.0
# idoos                       0.769231  0.714286  0.740741     14.0

# %%
sorted_dar
# Out:
#                            precision    recall  f1-score  support
# create_account              1.000000  1.000000  1.000000     19.0
# get_refund                  1.000000  1.000000  1.000000     18.0
# general_positive_feedback   1.000000  1.000000  1.000000     13.0
# general_negative_feedback   1.000000  1.000000  1.000000     14.0
# lost_or_stolen_phone        1.000000  1.000000  1.000000     12.0
# age_limit                   1.000000  1.000000  1.000000     12.0
# edit_account                1.000000  1.000000  1.000000     14.0
# delete_account              1.000000  1.000000  1.000000     19.0
# deactivate_my_card          1.000000  1.000000  1.000000     13.0
# get_invoice                 1.000000  1.000000  1.000000     20.0
# contact_human_agent         1.000000  1.000000  1.000000     19.0
# contact_customer_service    1.000000  1.000000  1.000000     19.0
# change_order                1.000000  1.000000  1.000000     18.0
# cancel_transfer             1.000000  1.000000  1.000000     13.0
# cancel_order                1.000000  1.000000  1.000000     15.0
# weighted avg                0.981393  0.980663  0.980539    362.0
# macro avg                   0.979835  0.978610  0.978695    362.0
# card_swallowed              0.941176  1.000000  0.969697     16.0
# exchange                    0.937500  1.000000  0.967742     15.0
# fee                         0.928571  1.000000  0.962963     13.0
# oodoos                      0.928571  1.000000  0.962963     13.0
# insurance                   1.000000  0.923077  0.960000     13.0
# loan                        1.000000  0.916667  0.956522     12.0
# compromised_card            1.000000  0.866667  0.928571     15.0
# activate_my_card            0.923077  0.923077  0.923077     13.0
# idoos                       0.857143  0.857143  0.857143     14.0

# %%
#for arabic, besides idoos, compromised card scores are low, so then if an utterance is compromised card, it is often misclassified as what?

# %%
df['intent_pred_ara'] = intent_pred_ara
df['intent_pred_dar'] = intent_pred_dar
df
# Out:
#                                                 arabic  \
# 0                                         هذا رائع جدا
# 1                      كيف يمكنني أن أضع طابعة جلدية ؟
# 2     أيمكنني إلغاء أمر للحصول على شهادة إيداع جديدة ؟
# 3                        معاملات مشكوك فيها على حسابي.
# 4               تم تأجيل المباراة ، ماذا علي أن أفعل ؟
# ..                                                 ...
# 357    أيمكنني أن أسأل عميلا ما هي ساعات دعم العملاء ؟
# 358  كيف لي أن أعرف إن كانت سياسة التأمين الخاصة بي...
# 359  أريد تغيير المعلومات عن بروفايلي ، كيف يمكنني ...
# 360  أيمكنك على الأقل أن تحاول أن تعالج شواغلي بدلا...
# 361  لقد سرقت كل شيء مني. لا يمكنني استخدام التطبيق...
#
#                                                 darija  \
# 0                                           هادشي واعر
# 1                              كيفاش نصلح طابعة عالقة؟
# 2             واش نقدر نلغي طلبية لشهادة ايداع جديدة؟
# 3                               عمليات مشبوهة فحسابي.
# 4                          تأجل الماتش، شنو لازم ندير؟
# ..                                                 ...
# 357          تقدر تسول  الوكيل على ساعات دعم الزبائن؟
# 358                  كيفاش نعرف بلي تأميني مازال ساري؟
# 359   بغيت نعدل المعلومات فبروفيل ديالي، كيفاش نديرها؟
# 360  تقدر تحاول تواجه مشاكلي بلا ما تعطيني جوابات ج...
# 361  كل شيء سُرق مني. لا أستطيع استخدام التطبيق. ير...
#
#      different from msa from 1 to 3                     intent  \
# 0                                 3  general_positive_feedback
# 1                                 2                     oodoos
# 2                                 2               cancel_order
# 3                                 1           compromised_card
# 4                                 3                 get_refund
# ..                              ...                        ...
# 357                               2   contact_customer_service
# 358                               2                  insurance
# 359                               2               edit_account
# 360                               1  general_negative_feedback
# 361                               1       lost_or_stolen_phone
#
#                intent_pred_ara            intent_pred_dar
# 0    general_positive_feedback  general_positive_feedback
# 1                       oodoos                     oodoos
# 2                 cancel_order               cancel_order
# 3             compromised_card           compromised_card
# 4                   get_refund                 get_refund
# ..                         ...                        ...
# 357   contact_customer_service   contact_customer_service
# 358                  insurance                  insurance
# 359               edit_account               edit_account
# 360  general_negative_feedback  general_negative_feedback
# 361       lost_or_stolen_phone       lost_or_stolen_phone
#
# [362 rows x 6 columns]

# %%
compro_card = df[df['intent']=="compromised_card"]
compro_card_preds = compro_card['intent_pred_ara'].tolist()

# %%
compro_card_preds, len(compro_card_preds)
# Out:
# (['compromised_card',
#   'compromised_card',
#   'compromised_card',
#   'compromised_card',
#   'compromised_card',
#   'compromised_card',
#   'compromised_card',
#   'compromised_card',
#   'compromised_card',
#   'general_negative_feedback',
#   'compromised_card',
#   'compromised_card',
#   'activate_my_card',
#   'compromised_card',
#   'compromised_card'],
#  15)

# %%
#only two errors but as they are few, the scores get low fast

# %%
df['intent'].value_counts()
# Out:
# intent
# get_invoice                  20
# contact_customer_service     19
# delete_account               19
# contact_human_agent          19
# create_account               19
# get_refund                   18
# change_order                 18
# card_swallowed               16
# exchange                     15
# cancel_order                 15
# compromised_card             15
# general_negative_feedback    14
# idoos                        14
# edit_account                 14
# cancel_transfer              13
# deactivate_my_card           13
# general_positive_feedback    13
# activate_my_card             13
# insurance                    13
# oodoos                       13
# fee                          13
# lost_or_stolen_phone         12
# loan                         12
# age_limit                    12
# Name: count, dtype: int64

# %%
# Iterate through each level of differences (0, 1, 2, 4) and filter by indices
for level in [1, 2, 3]:
    print(f"\nMetrics for Darija texts where difference level is {level}:")
    sub_df = df[df["different from msa from 1 to 3"] == level]
    sub_ground_truths = sub_df['intent'].tolist()
    sub_intent_pred_ara = sub_df['intent_pred_ara'].tolist()
    sub_intent_pred_dar = sub_df['intent_pred_dar'].tolist()
    #acc_msa, prec_msa, rec_msa, f1_msa = compute_metrics(sub_ground_truths, sub_intent_pred_ara)
    acc_dar, prec_dar, rec_dar, f1_dar = compute_metrics(sub_ground_truths, sub_intent_pred_dar)
    #print(acc_msa, prec_msa, rec_msa, f1_msa)
    print(acc_dar, prec_dar, rec_dar, f1_dar)
    print('-----------')
# Out:
# Metrics for Darija texts where difference level is 1:
# 0.9848484848484849 0.9848484848484848 0.9772727272727273 0.9757575757575758
# -----------
#
# Metrics for Darija texts where difference level is 2:
# 0.9775280898876404 0.9748842592592594 0.9725694444444445 0.9730312233589088
# -----------
#
# Metrics for Darija texts where difference level is 3:
# 1.0 1.0 1.0 1.0
# -----------

# %% [markdown]
# # Retriever Intent Detector

# %%
# !pip install --quiet faiss-gpu datasets
# !pip install --quiet  -U sentence-transformers
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 MB 9.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.1/249.1 kB 7.5 MB/s eta 0:00:00

# %%
from sentence_transformers import SentenceTransformer

pretrained_model = SentenceTransformer("intfloat/multilingual-e5-base")
# Out:
# modules.json:   0%|          | 0.00/387 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/179k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/57.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/694 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/418 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/280 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/200 [00:00<?, ?B/s]

# %%
import pandas as pd
df_train = pd.read_excel('train set 7 february 2024 from V6 reshaped.xlsx')

# %%
embeddings_normed = pretrained_model.encode(df_train['text'].tolist(), normalize_embeddings=True)

# %%
embeddings_test_dar_normed = pretrained_model.encode(dar, normalize_embeddings=True)
embeddings_test_ar_normed = pretrained_model.encode(ar, normalize_embeddings=True)

# %%
df_train
# Out:
#                                                    text                label  \
# 0                      i want a refund, help me egt one           get_refund
# 1     I want to download an invoice, can you show me...          get_invoice
# 2       can u ask an agent how I can obtain an invoice?          get_invoice
# 3          How do I dispute a charge on my credit card?                idoos
# 4             At what age can a person open an account?            age_limit
# ...                                                 ...                  ...
# 5775      كيفاش نقدر نلغي تحويلة دارت عبر حوالة مالية؟       cancel_transfer
# 5776                     ما بغيتش حسابي، عاونوني نمسحوه       delete_account
# 5777                  تم الغاء الحفلة، غادي تحصّل ردّة.           get_refund
# 5778    ما كتعاونيش، أشنو لازم ندير باش نهدر مع إنسان؟   contact_human_agent
# 5779  واش نقدر نشوف فشي بلاصة واش غايكونو رسوم على ا...                  fee
#
#      language
# 0          en
# 1          en
# 2          en
# 3          en
# 4          en
# ...       ...
# 5775       ar
# 5776       ar
# 5777       ar
# 5778       ar
# 5779       ar
#
# [5780 rows x 3 columns]

# %%
ground_truths_train = df_train['label'].tolist()

# %%
import faiss

index = faiss.IndexFlatL2(embeddings_normed.shape[1])
index.add(embeddings_normed)

query = embeddings_test_ar_normed
#y = y_test_darija
k = 1 # number of nearest neighbors to return
D, I = index.search(query, k)
predicted_intents_for_ar = [ground_truths_train[x[0]] for x in I.tolist()]

# %%
index = faiss.IndexFlatL2(embeddings_normed.shape[1])
index.add(embeddings_normed)

query = embeddings_test_dar_normed
#y = y_test_darija
k = 1 # number of nearest neighbors to return
D, I = index.search(query, k)
predicted_intents_for_dar = [ground_truths_train[x[0]] for x in I.tolist()]

# %%
ground_truths_test = df['intent'].tolist()

# %%
acc_msa, prec_msa, rec_msa, f1_msa = compute_metrics(ground_truths_test, predicted_intents_for_ar)
acc_dar, prec_dar, rec_dar, f1_dar = compute_metrics(ground_truths_test, predicted_intents_for_dar)
print(acc_msa, prec_msa, rec_msa, f1_msa)
print(acc_dar, prec_dar, rec_dar, f1_dar)
# Out:
# 0.8977900552486188 0.9049829277189958 0.8890199925561767 0.8891016422543996
# 0.8812154696132597 0.8819146922765345 0.8724208357432043 0.8714264631329186

# %%
report_ar = classification_report(ground_truths_test, predicted_intents_for_ar, output_dict=True)
report_dar = classification_report(ground_truths_test, predicted_intents_for_dar, output_dict=True)

# Convert dictionaries to DataFrames
df_ar = pd.DataFrame(report_ar).transpose()
df_dar = pd.DataFrame(report_dar).transpose()

# Remove the 'accuracy' row for sorting purposes
df_ar = df_ar.drop(['accuracy'])
df_dar = df_dar.drop(['accuracy'])

# Sort intents by F1-score
sorted_ar = df_ar.sort_values(by='f1-score', ascending=False)
sorted_dar = df_dar.sort_values(by='f1-score', ascending=False)

# %%
sorted_ar
# Out:
#                            precision    recall  f1-score  support
# general_positive_feedback   1.000000  1.000000  1.000000     13.0
# contact_customer_service    1.000000  1.000000  1.000000     19.0
# get_invoice                 0.952381  1.000000  0.975610     20.0
# change_order                0.947368  1.000000  0.972973     18.0
# get_refund                  1.000000  0.944444  0.971429     18.0
# cancel_transfer             0.928571  1.000000  0.962963     13.0
# insurance                   0.928571  1.000000  0.962963     13.0
# age_limit                   1.000000  0.916667  0.956522     12.0
# delete_account              0.947368  0.947368  0.947368     19.0
# cancel_order                0.882353  1.000000  0.937500     15.0
# exchange                    0.933333  0.933333  0.933333     15.0
# edit_account                0.928571  0.928571  0.928571     14.0
# create_account              0.863636  1.000000  0.926829     19.0
# oodoos                      0.923077  0.923077  0.923077     13.0
# lost_or_stolen_phone        1.000000  0.833333  0.909091     12.0
# weighted avg                0.906806  0.897790  0.895177    362.0
# macro avg                   0.904983  0.889020  0.889102    362.0
# deactivate_my_card          0.857143  0.923077  0.888889     13.0
# contact_human_agent         0.818182  0.947368  0.878049     19.0
# card_swallowed              0.928571  0.812500  0.866667     16.0
# loan                        0.833333  0.833333  0.833333     12.0
# compromised_card            0.750000  0.800000  0.774194     15.0
# general_negative_feedback   0.900000  0.642857  0.750000     14.0
# idoos                       0.818182  0.642857  0.720000     14.0
# activate_my_card            0.578947  0.846154  0.687500     13.0
# fee                         1.000000  0.461538  0.631579     13.0

# %%
sorted_dar
# Out:
#                            precision    recall  f1-score  support
# insurance                   1.000000  1.000000  1.000000     13.0
# get_refund                  0.947368  1.000000  0.972973     18.0
# contact_human_agent         1.000000  0.947368  0.972973     19.0
# cancel_order                1.000000  0.933333  0.965517     15.0
# edit_account                0.933333  1.000000  0.965517     14.0
# contact_customer_service    0.904762  1.000000  0.950000     19.0
# change_order                0.900000  1.000000  0.947368     18.0
# get_invoice                 0.904762  0.950000  0.926829     20.0
# create_account              0.900000  0.947368  0.923077     19.0
# general_positive_feedback   1.000000  0.846154  0.916667     13.0
# card_swallowed              0.933333  0.875000  0.903226     16.0
# exchange                    1.000000  0.800000  0.888889     15.0
# age_limit                   0.846154  0.916667  0.880000     12.0
# weighted avg                0.884132  0.881215  0.877234    362.0
# macro avg                   0.881915  0.872421  0.871426    362.0
# lost_or_stolen_phone        0.909091  0.833333  0.869565     12.0
# oodoos                      0.800000  0.923077  0.857143     13.0
# activate_my_card            0.800000  0.923077  0.857143     13.0
# cancel_transfer             0.846154  0.846154  0.846154     13.0
# deactivate_my_card          0.750000  0.923077  0.827586     13.0
# general_negative_feedback   0.846154  0.785714  0.814815     14.0
# compromised_card            0.800000  0.800000  0.800000     15.0
# fee                         0.833333  0.769231  0.800000     13.0
# delete_account              0.708333  0.894737  0.790698     19.0
# loan                        0.888889  0.666667  0.761905     12.0
# idoos                       0.714286  0.357143  0.476190     14.0

# %%
# the intents compromised_card, general_negative_feedback, idoos, activate_my_card, fee have low scores for Arabic
# the intents fee, delete_account, loan and idoos have low scores for Darija

# %%
df['intent_pred_ara_retriever'] = predicted_intents_for_ar
df['intent_pred_dar_retriever'] = predicted_intents_for_dar

# %%
# Iterate through each level of differences (0, 1, 2, 4) and filter by indices
for level in [1, 2, 3]:
    print(f"\nMetrics for Darija texts where difference level is {level}:")
    sub_df = df[df["different from msa from 1 to 3"] == level]
    sub_ground_truths = sub_df['intent'].tolist()
    sub_intent_pred_ara = sub_df['intent_pred_ara_retriever'].tolist()
    sub_intent_pred_dar = sub_df['intent_pred_dar_retriever'].tolist()
    #acc_msa, prec_msa, rec_msa, f1_msa = compute_metrics(sub_ground_truths, sub_intent_pred_ara)
    acc_dar, prec_dar, rec_dar, f1_dar = compute_metrics(sub_ground_truths, sub_intent_pred_dar)
    #print(acc_msa, prec_msa, rec_msa, f1_msa)
    print(acc_dar, prec_dar, rec_dar, f1_dar)
    print('-----------')
# Out:
# Metrics for Darija texts where difference level is 1:
# 0.8181818181818182 0.7130434782608696 0.7401656314699794 0.7012260686173729
# -----------
#
# Metrics for Darija texts where difference level is 2:
# 0.9101123595505618 0.9159705694632166 0.8994858364101787 0.9024178136907812
# -----------
#
# Metrics for Darija texts where difference level is 3:
# 0.7586206896551724 0.6833333333333333 0.65 0.65
# -----------

# %%
# when the darija is too close to MSA, the model gets lost
# when the darija is too far from MSA, the model gets lost too
# when the darija is simple darija not very far from MSA and not very close to it, the model have good understanding of it

# %% [markdown]
# # Intent Classification by ChatGPT Prompting

# %%
prompt = """Context: You are an advanced banking chatbot designed for a Moroccan bank, equipped to assist customers with a range of inquiries and services related to banking. Your capabilities extend from handling basic account management to addressing complex service requests. Your primary objective is to accurately discern the customer's intent from their utterances, using the list of predefined intents to provide relevant assistance or guide them to the appropriate service channel.

Here is the list of all intents and their meanings:
- activate_my_card: Initiate the use of a new banking card.
- age_limit: Inquire about the minimum age requirement for a service.
- cancel_order: Request to cancel a previously placed order.
- cancel_transfer: Request to cancel a previously initiated money transfer.
- card_swallowed: Report an ATM machine retaining a banking card.
- change_order: Modify details of a previously placed order.
- compromised_card: Report a banking card suspected of being at risk of fraud.
- contact_customer_service: Request for assistance from the bank’s customer service.
- contact_human_agent: Seek to speak with a live customer support agent.
- create_account: Initiate the process of opening a new bank account.
- deactivate_my_card: Disable a currently active banking card.
- delete_account: Request the closure of a bank account.
- edit_account: Make changes to the account information.
- exchange: Inquire about currency exchange services.
- fee: Question about the charges associated with a service.
- general_negative_feedback: Provide negative feedback on the overall service.
- general_positive_feedback: Provide positive feedback on the overall service.
- get_invoice: Request a bill or invoice for a transaction.
- get_refund: Request a return of funds for a transaction.
- insurance: Inquire about insurance products offered by the bank.
- loan: Request information on loan products.
- lost_or_stolen_phone: Report a lost or stolen phone linked to mobile banking.
- idoos: An intent not in the list of intents but within the banking domain, like asking for Western Union facilities.
- oodoos: An intent not in the list of intents and not related to banking, like asking the distance between the Earth and the Moon.

When you receive the 5 utterances from a customer, analyze the content to determine the most applicable intents. Consider the context of banking practices in Morocco, including services and customer expectations.

Instructions:
1. Read the customer's utterances carefully.
2. Identify the most relevant intent for each utterance from the predefined list.
3. Return the detected intents in JSON format for easy parsing:

```
{"intents": ["intent1", "intent2", "intent3", "intent4", "intent5"]}
```

Make sure to return only one intent for each utterance. Select the intent that best matches the customer's query or service need for each of the five utterances. If an utterance does not fit any predefined intents or falls outside the banking domain, use "oodoos" for unrelated queries and "idoos" for banking-related queries not listed among the predefined intents.
Here are the five utterances:
"""

# %%
import pandas as pd
df = pd.read_excel('test data annotated far from msa sept 2024.xlsx')
ground_truths = df['intent'].tolist()
df['darija'] = df['darija'].astype(str)
dar = df['darija'].tolist()

# %%
batched_darija_texts = [dar[k:k+5] for k in range(0,len(dar),5)]

# %%
len(dar), len(batched_darija_texts)
# Out:
# (362, 73)

# %%
prompted_batched_dar = [prompt + "\n".join(x) for x in batched_darija_texts]

# %%
len(prompted_batched_dar)
# Out:
# 73

# %%
from random import choice
print(choice(prompted_batched_dar))
# Out:
# Context: You are an advanced banking chatbot designed for a Moroccan bank, equipped to assist customers with a range of inquiries and services related to banking. Your capabilities extend from handling basic account management to addressing complex service requests. Your primary objective is to accurately discern the customer's intent from their utterances, using the list of predefined intents to provide relevant assistance or guide them to the appropriate service channel.
#
# Here is the list of all intents and their meanings:
# - activate_my_card: Initiate the use of a new banking card.
# - age_limit: Inquire about the minimum age requirement for a service.
# - cancel_order: Request to cancel a previously placed order.
# - cancel_transfer: Request to cancel a previously initiated money transfer.
# - card_swallowed: Report an ATM machine retaining a banking card.
# - change_order: Modify details of a previously placed order.
# - compromised_card: Report a banking card suspected of being at risk of fraud.
# - contact_customer_service: Request for assistance from the bank’s customer service.
# - contact_human_agent: Seek to speak with a live customer support agent.
# - create_account: Initiate the process of opening a new bank account.
# - deactivate_my_card: Disable a currently active banking card.
# - delete_account: Request the closure of a bank account.
# - edit_account: Make changes to the account information.
# - exchange: Inquire about currency exchange services.
# - fee: Question about the charges associated with a service.
# - general_negative_feedback: Provide negative feedback on the overall service.
# - general_positive_feedback: Provide positive feedback on the overall service.
# - get_invoice: Request a bill or invoice for a transaction.
# - get_refund: Request a return of funds for a transaction.
# - insurance: Inquire about insurance products offered by the bank.
# - loan: Request information on loan products.
# - lost_or_stolen_phone: Report a lost or stolen phone linked to mobile banking.
# - idoos: An intent not in the list of intents but within the banking domain, like asking for Western Union facilities.
# - oodoos: An intent not in the list of intents and not related to banking, like asking the distance between the Earth and the Moon.
#
# When you receive the 5 utterances from a customer, analyze the content to determine the most applicable intents. Consider the context of banking practices in Morocco, including services and customer expectations.
#
# Instructions:
# 1. Read the customer's utterances carefully.
# 2. Identify the most relevant intent for each utterance from the predefined list.
# 3. Return the detected intents in JSON format for easy parsing:
#
# ```
# {"intents": ["intent1", "intent2", "intent3", "intent4", "intent5"]}
# ```
#
# Make sure to return only one intent for each utterance. Select the intent that best matches the customer's query or service need for each of the five utterances. If an utterance does not fit any predefined intents or falls outside the banking domain, use "oodoos" for unrelated queries and "idoos" for banking-related queries not listed among the predefined intents.
# Here are the five utterances:
# شريت حاجة، كيفاش نقدر نعدل شراء ديالي؟
# كنتقدمولي نصائح شخصية باش نستثمر؟
# بغيت نعمل تغيير فشراء ديالي
# واش يمكن ناخد تغطية تأمينية للأشياء لي ماكايناش في البوليسات القياسية؟
# واش نقدر نفتح حساب توفير صحي لوليد لي هو قاصر؟

# %%
# !pip install openai
# Out:
# Collecting openai
#   Downloading openai-1.46.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Downloading jiter-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.9.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.8)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.3 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.23.3)
# Downloading openai-1.46.0-py3-none-any.whl (375 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 375.0/375.0 kB 7.9 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 4.8 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.8 MB/s eta 0:00:00
# Downloading jiter-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (318 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 17.2 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.1 MB/s eta 0:00:00
# Installing collected packages: jiter, h11, httpcore, httpx, openai
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.2 jiter-0.5.0 openai-1.46.0

# %%
from openai import OpenAI
client = OpenAI(api_key="sk-...")

def use_chatgpt(prompt):
    response = client.chat.completions.create(
      model="gpt-4-turbo-preview",
      messages=[
        {"role": "user", "content": prompt}
      ]
    )
    return response.choices[0].message.content

# %%
resp0 = use_chatgpt(prompted_batched_dar[0])
resp0
# Out:
# '```\n{"intents": ["general_positive_feedback", "oodoos", "cancel_order", "compromised_card", "oodoos"]}\n```'

# %%
from tqdm import tqdm
answers = [resp0]
for x in tqdm(prompted_batched_dar[1:]):
    answers.append(use_chatgpt(x))
# Out:
# 100%|██████████| 72/72 [01:30<00:00,  1.26s/it]

# %%
import pickle

with open('chatgpt4_darija_intent_detection_on_test_17sept2024.pickle', 'wb') as handle:
    pickle.dump(answers, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
import pickle
with open('chatgpt4_darija_intent_detection_on_test_17sept2024.pickle', 'rb') as handle:
    answers = pickle.load(handle)

# %%
answers
# Out:
# ['```\n{"intents": ["general_positive_feedback", "oodoos", "cancel_order", "compromised_card", "oodoos"]}\n```',
#  '```\n{"intents": ["oodoos", "cancel_order", "contact_customer_service", "get_refund", "contact_customer_service"]}\n```',
#  '```\n{"intents": ["card_swallowed", "fee", "contact_customer_service", "contact_customer_service", "change_order"]}\n```',
#  '```\n{"intents": ["delete_account", "compromised_card", "oodoos", "contact_customer_service", "contact_human_agent"]}\n```',
#  '```\n{"intents": ["change_order", "contact_human_agent", "loan", "contact_human_agent", "compromised_card"]}\n```',
#  '```\n{"intents": ["get_refund", "get_refund", "card_swallowed", "idoos", "delete_account"]}\n```',
#  '```\n{"intents": ["compromised_card", "insurance", "activate_my_card", "get_invoice", "delete_account"]}\n```',
#  '```\n{"intents": ["change_order", "idoos", "change_order", "idoos", "idoos"]}\n```',
#  '```\n{"intents": ["cancel_order", "idoos", "idoos", "delete_account", "loan"]}\n```',
#  '```\n{"intents": ["get_refund", "cancel_order", "lost_or_stolen_phone", "contact_human_agent", "idoos"]}\n```',
#  '```\n{"intents": ["insurance", "general_positive_feedback", "oodoos", "oodoos", "change_order"]}\n```',
#  '```\n{"intents": ["idoos", "contact_customer_service", "get_refund", "contact_customer_service", "idoos"]}\n```',
#  '```\n{"intents": ["get_refund", "edit_account", "deactivate_my_card", "activate_my_card", "contact_human_agent"]}\n```',
#  '```\n{"intents": ["cancel_transfer", "oodoos", "general_negative_feedback", "card_swallowed", "idoos"]}\n```',
#  '```\n{"intents": ["activate_my_card", "delete_account", "delete_account", "exchange", "fee"]}\n```',
#  '```\n{"intents": ["oodoos", "idoos", "change_order", "idoos", "fee"]}\n```',
#  '```\n{"intents": ["idoos", "edit_account", "delete_account", "general_positive_feedback", "exchange"]}\n```',
#  '```\n{"intents": ["delete_account", "fee", "create_account", "change_order", "loan"]}\n```',
#  '```\n{"intents": ["idoos", "exchange", "contact_human_agent", "contact_human_agent", "cancel_order"]}\n```',
#  '```\n{"intents": ["create_account", "get_invoice", "exchange", "get_refund", "cancel_order"]}\n```',
#  '```\n{"intents": ["exchange", "get_refund", "card_swallowed", "idoos", "cancel_transfer"]}\n```',
#  '```\n{"intents": ["cancel_transfer", "get_invoice", "cancel_order", "contact_human_agent", "create_account"]}\n```',
#  '```\n{"intents": ["change_order", "idoos", "loan", "idoos", "age_limit"]}\n```',
#  '```\n{"intents": ["general_positive_feedback", "idoos", "fee", "idoos", "exchange"]}\n```',
#  '```\n{"intents": ["idoos", "delete_account", "contact_human_agent", "get_refund", "activate_my_card"]}\n```',
#  '```\n{"intents": ["oodoos", "idoos", "idoos", "activate_my_card", "lost_or_stolen_phone"]}\n```',
#  '```\n{"intents": ["oodoos", "general_negative_feedback", "fee", "general_positive_feedback", "delete_account"]}\n```',
#  '```\n{"intents": ["activate_my_card", "get_refund", "insurance", "idoos", "contact_human_agent"]}\n```',
#  '```\n{"intents": ["contact_customer_service", "insurance", "get_invoice", "oodoos", "contact_customer_service"]}\n```',
#  '```\n{"intents": ["general_negative_feedback", "contact_customer_service", "oodoos", "contact_human_agent", "create_account"]}\n```',
#  '```\n{"intents": ["compromised_card", "contact_human_agent", "fee", "idoos", "get_refund"]}\n```',
#  '```\n{"intents": ["cancel_transfer", "create_account", "get_invoice", "change_order", "edit_account"]}\n```',
#  '```\n{"intents": ["fee", "get_invoice", "get_refund", "cancel_transfer", "contact_human_agent"]}\n```',
#  '```\n{"intents": ["general_negative_feedback", "contact_human_agent", "cancel_transfer", "change_order", "exchange"]}\n```',
#  '```\n{"intents": ["fee", "create_account", "general_negative_feedback", "general_positive_feedback", "exchange"]}\n```',
#  '```\n{"intents": ["card_swallowed", "age_limit", "general_negative_feedback", "create_account", "oodoos"]}\n```',
#  '```\n{"intents": ["insurance", "contact_human_agent", "change_order", "cancel_order", "general_negative_feedback"]}\n```',
#  '```\n{"intents": ["age_limit", "contact_human_agent", "change_order", "cancel_order", "compromised_card"]}\n```',
#  '```\n{"intents": ["contact_human_agent", "general_positive_feedback", "oodoos", "edit_account", "get_invoice"]}\n```',
#  '```\n{"intents": ["deactivate_my_card", "contact_human_agent", "idoos", "contact_human_agent", "lost_or_stolen_phone"]}\n```',
#  '```\n{"intents": ["activate_my_card", "cancel_transfer", "contact_human_agent", "lost_or_stolen_phone", "get_invoice"]}\n```',
#  '```\n{"intents": ["insurance", "get_refund", "idoos", "activate_my_card", "loan"]}\n```',
#  '```\n{"intents": ["get_invoice", "compromised_card", "delete_account", "cancel_transfer", "contact_customer_service"]}\n```',
#  '```\n{"intents": ["insurance", "fee", "delete_account", "loan", "oodoos"]}\n```',
#  '```\n{"intents": ["contact_human_agent", "cancel_order", "oodoos", "edit_account", "delete_account"]}\n```',
#  '```\n{"intents": ["contact_human_agent", "delete_account", "deactivate_my_card", "oodoos", "card_swallowed"]}\n```',
#  '```\n{"intents": ["card_swallowed", "cancel_order", "idoos", "get_invoice", "contact_human_agent"]}\n```',
#  '```\n{"intents": ["contact_human_agent", "exchange", "get_invoice", "idoos", "idoos"]}\n```',
#  '```\n{"intents": ["deactivate_my_card", "exchange", "get_invoice", "get_invoice", "loan"]}\n```',
#  '```\n{"intents": ["idoos", "loan", "create_account", "cancel_transfer", "edit_account"]}\n```',
#  '```\n{"intents": ["card_swallowed", "contact_customer_service", "general_positive_feedback", "edit_account", "activate_my_card"]}\n```',
#  '```\n{"intents": ["reactivate_my_card", "get_refund", "deactivate_my_card", "compromised_card", "get_refund"]}\n```',
#  '```\n{"intents": ["deactivate_my_card", "cancel_transfer", "change_order", "age_limit", "card_swallowed"]}\n```',
#  '```\n{"intents": ["oodoos", "deactivate_my_card", "create_account", "edit_account", "delete_account"]}\n```',
#  '```\n{"intents": ["cancel_order", "contact_human_agent", "change_order", "compromised_card", "idoos"]}\n```',
#  '```\n{"intents": ["contact_customer_service", "lost_or_stolen_phone", "fee", "idoos", "cancel_transfer"]}\n```',
#  '```\n{"intents": ["card_swallowed", "contact_human_agent", "loan", "change_order"]}\n```',
#  '```\n{"intents": ["idoos", "idoos", "compromised_card", "activate_my_card", "contact_customer_service"]}\n```',
#  '```\n{"intents": ["create_account", "oodoos", "general_positive_feedback", "cancel_order", "lost_or_stolen_phone"]}\n```',
#  '```\n{"intents": ["edit_account", "contact_customer_service", "cancel_transfer", "exchange", "idoos"]}\n```',
#  '```\n{"intents": ["edit_account", "contact_customer_service", "get_refund", "general_positive_feedback", "lost_or_stolen_phone"]}\n```',
#  '```\n{"intents": ["idoos", "general_negative_feedback", "fee", "contact_customer_service", "change_order"]}\n```',
#  '```json\n{\n  "intents": ["oodoos", "lost_or_stolen_phone", "change_order", "lost_or_stolen_phone", "deactivate_my_card"]\n}\n```',
#  '```\n{"intents": ["create_account", "delete_account", "delete_account", "exchange", "idoos"]}\n```',
#  '```\n{"intents": ["delete_account", "create_account", "activate_my_card", "oodoos", "contact_customer_service"]}\n```',
#  '```\n{"intents": ["cancel_transfer", "idoos", "contact_human_agent", "get_invoice", "contact_customer_service"]}\n```',
#  '```\n{"intents": ["change_order", "age_limit", "contact_customer_service", "compromised_card", "activate_my_card"]}\n```',
#  '```\n{"intents": ["cancel_transfer", "cancel_transfer", "contact_human_agent", "idoos", "idoos"]}\n```',
#  '```json\n{"intents": ["get_invoice", "oodoos", "cancel_order", "oodoos", "delete_account"]}\n```',
#  '```\n{"intents": ["card_swallowed", "idoos", "get_invoice", "oodoos", "age_limit"]}\n```',
#  '```\n{"intents": ["cancel_transfer", "idoos", "cancel_order", "lost_or_stolen_phone", "get_invoice"]}\n```',
#  '```\n{"intents": ["fee", "idoos", "contact_human_agent", "insurance", "edit_account"]}\n```',
#  '```\n{"intents": ["contact_human_agent", "lost_or_stolen_phone"]}\n```']

# %%
predicted_intents_dar = []
for j, x in enumerate(answers):
    next_predictions = eval(x.strip("`").strip().strip('json').strip())['intents']
    if len(next_predictions) != 5:
        print('bizarre')
        print(j)
    predicted_intents_dar.extend(next_predictions)
# Out:
# bizarre
# 56
# bizarre
# 72

# %%
x = answers[56]
x
# Out:
# '```\n{"intents": ["card_swallowed", "contact_human_agent", "loan", "change_order"]}\n```'

# %%
print(prompted_batched_dar[56])
# Out:
# Context: You are an advanced banking chatbot designed for a Moroccan bank, equipped to assist customers with a range of inquiries and services related to banking. Your capabilities extend from handling basic account management to addressing complex service requests. Your primary objective is to accurately discern the customer's intent from their utterances, using the list of predefined intents to provide relevant assistance or guide them to the appropriate service channel.
#
# Here is the list of all intents and their meanings:
# - activate_my_card: Initiate the use of a new banking card.
# - age_limit: Inquire about the minimum age requirement for a service.
# - cancel_order: Request to cancel a previously placed order.
# - cancel_transfer: Request to cancel a previously initiated money transfer.
# - card_swallowed: Report an ATM machine retaining a banking card.
# - change_order: Modify details of a previously placed order.
# - compromised_card: Report a banking card suspected of being at risk of fraud.
# - contact_customer_service: Request for assistance from the bank’s customer service.
# - contact_human_agent: Seek to speak with a live customer support agent.
# - create_account: Initiate the process of opening a new bank account.
# - deactivate_my_card: Disable a currently active banking card.
# - delete_account: Request the closure of a bank account.
# - edit_account: Make changes to the account information.
# - exchange: Inquire about currency exchange services.
# - fee: Question about the charges associated with a service.
# - general_negative_feedback: Provide negative feedback on the overall service.
# - general_positive_feedback: Provide positive feedback on the overall service.
# - get_invoice: Request a bill or invoice for a transaction.
# - get_refund: Request a return of funds for a transaction.
# - insurance: Inquire about insurance products offered by the bank.
# - loan: Request information on loan products.
# - lost_or_stolen_phone: Report a lost or stolen phone linked to mobile banking.
# - idoos: An intent not in the list of intents but within the banking domain, like asking for Western Union facilities.
# - oodoos: An intent not in the list of intents and not related to banking, like asking the distance between the Earth and the Moon.
#
# When you receive the 5 utterances from a customer, analyze the content to determine the most applicable intents. Consider the context of banking practices in Morocco, including services and customer expectations.
#
# Instructions:
# 1. Read the customer's utterances carefully.
# 2. Identify the most relevant intent for each utterance from the predefined list.
# 3. Return the detected intents in JSON format for easy parsing:
#
# ```
# {"intents": ["intent1", "intent2", "intent3", "intent4", "intent5"]}
# ```
#
# Make sure to return only one intent for each utterance. Select the intent that best matches the customer's query or service need for each of the five utterances. If an utterance does not fit any predefined intents or falls outside the banking domain, use "oodoos" for unrelated queries and "idoos" for banking-related queries not listed among the predefined intents.
# Here are the five utterances:
# واش الف؟ حاولت نسحب فلوس من بنك Metro على شارع High St. Kensington وبلا أي إشعار تقلع الكارط فالماكينة. البنك كان مسكر ماقدرتش ندير شي حاجة. كيفاش نرجعها؟
# الخارج
# أجوبة ديالك ما كتعالجش المشكل لي عندي، واش تقدر تزيد لمستوى أعلى؟
# شحال ديال المال ممكن ناخد؟
# بغيت نبدل فشراء ديالي

# %%
#we redo the inference to get 5 answers not 4
use_chatgpt(prompted_batched_dar[56])
# Out:
# '```\n{"intents": ["card_swallowed", "contact_human_agent", "loan", "change_order"]}\n```'

# %%
answers[56] = '```{"intents": ["card_swallowed","exchange", "contact_human_agent", "loan", "change_order"]}```'

# %%
predicted_intents_dar = []
for j, x in enumerate(answers):
    next_predictions = eval(x.strip("`").strip().strip('json').strip())['intents']
    if len(next_predictions) != 5:
        print('bizarre')
        print(j)
    predicted_intents_dar.extend(next_predictions)
# Out:
# bizarre
# 72

# %%
predicted_intents_dar
# Out:
# ['general_positive_feedback',
#  'oodoos',
#  'cancel_order',
#  'compromised_card',
#  'oodoos',
#  'oodoos',
#  'cancel_order',
#  'contact_customer_service',
#  'get_refund',
#  'contact_customer_service',
#  'card_swallowed',
#  'fee',
#  'contact_customer_service',
#  'contact_customer_service',
#  'change_order',
#  'delete_account',
#  'compromised_card',
#  'oodoos',
#  'contact_customer_service',
#  'contact_human_agent',
#  'change_order',
#  'contact_human_agent',
#  'loan',
#  'contact_human_agent',
#  'compromised_card',
#  'get_refund',
#  'get_refund',
#  'card_swallowed',
#  'idoos',
#  'delete_account',
#  'compromised_card',
#  'insurance',
#  'activate_my_card',
#  'get_invoice',
#  'delete_account',
#  'change_order',
#  'idoos',
#  'change_order',
#  'idoos',
#  'idoos',
#  'cancel_order',
#  'idoos',
#  'idoos',
#  'delete_account',
#  'loan',
#  'get_refund',
#  'cancel_order',
#  'lost_or_stolen_phone',
#  'contact_human_agent',
#  'idoos',
#  'insurance',
#  'general_positive_feedback',
#  'oodoos',
#  'oodoos',
#  'change_order',
#  'idoos',
#  'contact_customer_service',
#  'get_refund',
#  'contact_customer_service',
#  'idoos',
#  'get_refund',
#  'edit_account',
#  'deactivate_my_card',
#  'activate_my_card',
#  'contact_human_agent',
#  'cancel_transfer',
#  'oodoos',
#  'general_negative_feedback',
#  'card_swallowed',
#  'idoos',
#  'activate_my_card',
#  'delete_account',
#  'delete_account',
#  'exchange',
#  'fee',
#  'oodoos',
#  'idoos',
#  'change_order',
#  'idoos',
#  'fee',
#  'idoos',
#  'edit_account',
#  'delete_account',
#  'general_positive_feedback',
#  'exchange',
#  'delete_account',
#  'fee',
#  'create_account',
#  'change_order',
#  'loan',
#  'idoos',
#  'exchange',
#  'contact_human_agent',
#  'contact_human_agent',
#  'cancel_order',
#  'create_account',
#  'get_invoice',
#  'exchange',
#  'get_refund',
#  'cancel_order',
#  'exchange',
#  'get_refund',
#  'card_swallowed',
#  'idoos',
#  'cancel_transfer',
#  'cancel_transfer',
#  'get_invoice',
#  'cancel_order',
#  'contact_human_agent',
#  'create_account',
#  'change_order',
#  'idoos',
#  'loan',
#  'idoos',
#  'age_limit',
#  'general_positive_feedback',
#  'idoos',
#  'fee',
#  'idoos',
#  'exchange',
#  'idoos',
#  'delete_account',
#  'contact_human_agent',
#  'get_refund',
#  'activate_my_card',
#  'oodoos',
#  'idoos',
#  'idoos',
#  'activate_my_card',
#  'lost_or_stolen_phone',
#  'oodoos',
#  'general_negative_feedback',
#  'fee',
#  'general_positive_feedback',
#  'delete_account',
#  'activate_my_card',
#  'get_refund',
#  'insurance',
#  'idoos',
#  'contact_human_agent',
#  'contact_customer_service',
#  'insurance',
#  'get_invoice',
#  'oodoos',
#  'contact_customer_service',
#  'general_negative_feedback',
#  'contact_customer_service',
#  'oodoos',
#  'contact_human_agent',
#  'create_account',
#  'compromised_card',
#  'contact_human_agent',
#  'fee',
#  'idoos',
#  'get_refund',
#  'cancel_transfer',
#  'create_account',
#  'get_invoice',
#  'change_order',
#  'edit_account',
#  'fee',
#  'get_invoice',
#  'get_refund',
#  'cancel_transfer',
#  'contact_human_agent',
#  'general_negative_feedback',
#  'contact_human_agent',
#  'cancel_transfer',
#  'change_order',
#  'exchange',
#  'fee',
#  'create_account',
#  'general_negative_feedback',
#  'general_positive_feedback',
#  'exchange',
#  'card_swallowed',
#  'age_limit',
#  'general_negative_feedback',
#  'create_account',
#  'oodoos',
#  'insurance',
#  'contact_human_agent',
#  'change_order',
#  'cancel_order',
#  'general_negative_feedback',
#  'age_limit',
#  'contact_human_agent',
#  'change_order',
#  'cancel_order',
#  'compromised_card',
#  'contact_human_agent',
#  'general_positive_feedback',
#  'oodoos',
#  'edit_account',
#  'get_invoice',
#  'deactivate_my_card',
#  'contact_human_agent',
#  'idoos',
#  'contact_human_agent',
#  'lost_or_stolen_phone',
#  'activate_my_card',
#  'cancel_transfer',
#  'contact_human_agent',
#  'lost_or_stolen_phone',
#  'get_invoice',
#  'insurance',
#  'get_refund',
#  'idoos',
#  'activate_my_card',
#  'loan',
#  'get_invoice',
#  'compromised_card',
#  'delete_account',
#  'cancel_transfer',
#  'contact_customer_service',
#  'insurance',
#  'fee',
#  'delete_account',
#  'loan',
#  'oodoos',
#  'contact_human_agent',
#  'cancel_order',
#  'oodoos',
#  'edit_account',
#  'delete_account',
#  'contact_human_agent',
#  'delete_account',
#  'deactivate_my_card',
#  'oodoos',
#  'card_swallowed',
#  'card_swallowed',
#  'cancel_order',
#  'idoos',
#  'get_invoice',
#  'contact_human_agent',
#  'contact_human_agent',
#  'exchange',
#  'get_invoice',
#  'idoos',
#  'idoos',
#  'deactivate_my_card',
#  'exchange',
#  'get_invoice',
#  'get_invoice',
#  'loan',
#  'idoos',
#  'loan',
#  'create_account',
#  'cancel_transfer',
#  'edit_account',
#  'card_swallowed',
#  'contact_customer_service',
#  'general_positive_feedback',
#  'edit_account',
#  'activate_my_card',
#  'reactivate_my_card',
#  'get_refund',
#  'deactivate_my_card',
#  'compromised_card',
#  'get_refund',
#  'deactivate_my_card',
#  'cancel_transfer',
#  'change_order',
#  'age_limit',
#  'card_swallowed',
#  'oodoos',
#  'deactivate_my_card',
#  'create_account',
#  'edit_account',
#  'delete_account',
#  'cancel_order',
#  'contact_human_agent',
#  'change_order',
#  'compromised_card',
#  'idoos',
#  'contact_customer_service',
#  'lost_or_stolen_phone',
#  'fee',
#  'idoos',
#  'cancel_transfer',
#  'card_swallowed',
#  'exchange',
#  'contact_human_agent',
#  'loan',
#  'change_order',
#  'idoos',
#  'idoos',
#  'compromised_card',
#  'activate_my_card',
#  'contact_customer_service',
#  'create_account',
#  'oodoos',
#  'general_positive_feedback',
#  'cancel_order',
#  'lost_or_stolen_phone',
#  'edit_account',
#  'contact_customer_service',
#  'cancel_transfer',
#  'exchange',
#  'idoos',
#  'edit_account',
#  'contact_customer_service',
#  'get_refund',
#  'general_positive_feedback',
#  'lost_or_stolen_phone',
#  'idoos',
#  'general_negative_feedback',
#  'fee',
#  'contact_customer_service',
#  'change_order',
#  'oodoos',
#  'lost_or_stolen_phone',
#  'change_order',
#  'lost_or_stolen_phone',
#  'deactivate_my_card',
#  'create_account',
#  'delete_account',
#  'delete_account',
#  'exchange',
#  'idoos',
#  'delete_account',
#  'create_account',
#  'activate_my_card',
#  'oodoos',
#  'contact_customer_service',
#  'cancel_transfer',
#  'idoos',
#  'contact_human_agent',
#  'get_invoice',
#  'contact_customer_service',
#  'change_order',
#  'age_limit',
#  'contact_customer_service',
#  'compromised_card',
#  'activate_my_card',
#  'cancel_transfer',
#  'cancel_transfer',
#  'contact_human_agent',
#  'idoos',
#  'idoos',
#  'get_invoice',
#  'oodoos',
#  'cancel_order',
#  'oodoos',
#  'delete_account',
#  'card_swallowed',
#  'idoos',
#  'get_invoice',
#  'oodoos',
#  'age_limit',
#  'cancel_transfer',
#  'idoos',
#  'cancel_order',
#  'lost_or_stolen_phone',
#  'get_invoice',
#  'fee',
#  'idoos',
#  'contact_human_agent',
#  'insurance',
#  'edit_account',
#  'contact_human_agent',
#  'lost_or_stolen_phone']

# %%
accuracy, precision, recall, f1_score = compute_metrics(ground_truths, predicted_intents_dar)
accuracy, precision, recall, f1_score
# Out:
# (0.8038674033149171, 0.8444655951283857, 0.766803129618919, 0.7803068132866307)

# %%
len(ground_truths)
# Out:
# 362

# %%
len(predicted_intents_dar)
# Out:
# 362

# %%
report_dar = classification_report(ground_truths, predicted_intents_dar, output_dict=True)

df_dar = pd.DataFrame(report_dar).transpose()

df_dar = df_dar.drop(['accuracy'])

sorted_dar = df_dar.sort_values(by='f1-score', ascending=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
df_dar.sort_values(by='f1-score', ascending=False)
# Out:
#                            precision    recall  f1-score  support
# change_order                1.000000  1.000000  1.000000     18.0
# cancel_order                1.000000  1.000000  1.000000     15.0
# delete_account              1.000000  1.000000  1.000000     19.0
# activate_my_card            1.000000  0.923077  0.960000     13.0
# lost_or_stolen_phone        1.000000  0.916667  0.956522     12.0
# exchange                    1.000000  0.866667  0.928571     15.0
# fee                         0.923077  0.923077  0.923077     13.0
# get_invoice                 1.000000  0.850000  0.918919     20.0
# cancel_transfer             0.812500  1.000000  0.896552     13.0
# edit_account                1.000000  0.785714  0.880000     14.0
# contact_customer_service    0.850000  0.894737  0.871795     19.0
# general_positive_feedback   1.000000  0.769231  0.869565     13.0
# get_refund                  0.875000  0.777778  0.823529     18.0
# weighted avg                0.877973  0.803867  0.816175    362.0
# card_swallowed              1.000000  0.687500  0.814815     16.0
# macro avg                   0.844466  0.766803  0.780307    362.0
# deactivate_my_card          1.000000  0.615385  0.761905     13.0
# insurance                   1.000000  0.615385  0.761905     13.0
# loan                        0.888889  0.666667  0.761905     12.0
# contact_human_agent         0.600000  0.947368  0.734694     19.0
# oodoos                      0.541667  1.000000  0.702703     13.0
# compromised_card            0.818182  0.600000  0.692308     15.0
# age_limit                   1.000000  0.500000  0.666667     12.0
# create_account              0.750000  0.473684  0.580645     19.0
# general_negative_feedback   0.750000  0.428571  0.545455     14.0
# idoos                       0.302326  0.928571  0.456140     14.0
# reactivate_my_card          0.000000  0.000000  0.000000      0.0

# %%
#create_account, general_negative_feedback, idoos have lower scores
# gpt4 have invented an intent "reactivate_my_card" which was not one of the predefined intents

# %%
df['intent_pred_dar_chatgpt'] = predicted_intents_dar
df
# Out:
#                                                 arabic  \
# 0                                         هذا رائع جدا
# 1                      كيف يمكنني أن أضع طابعة جلدية ؟
# 2     أيمكنني إلغاء أمر للحصول على شهادة إيداع جديدة ؟
# 3                        معاملات مشكوك فيها على حسابي.
# 4               تم تأجيل المباراة ، ماذا علي أن أفعل ؟
# ..                                                 ...
# 357    أيمكنني أن أسأل عميلا ما هي ساعات دعم العملاء ؟
# 358  كيف لي أن أعرف إن كانت سياسة التأمين الخاصة بي...
# 359  أريد تغيير المعلومات عن بروفايلي ، كيف يمكنني ...
# 360  أيمكنك على الأقل أن تحاول أن تعالج شواغلي بدلا...
# 361  لقد سرقت كل شيء مني. لا يمكنني استخدام التطبيق...
#
#                                                 darija  \
# 0                                           هادشي واعر
# 1                              كيفاش نصلح طابعة عالقة؟
# 2             واش نقدر نلغي طلبية لشهادة ايداع جديدة؟
# 3                               عمليات مشبوهة فحسابي.
# 4                          تأجل الماتش، شنو لازم ندير؟
# ..                                                 ...
# 357          تقدر تسول  الوكيل على ساعات دعم الزبائن؟
# 358                  كيفاش نعرف بلي تأميني مازال ساري؟
# 359   بغيت نعدل المعلومات فبروفيل ديالي، كيفاش نديرها؟
# 360  تقدر تحاول تواجه مشاكلي بلا ما تعطيني جوابات ج...
# 361  كل شيء سُرق مني. لا أستطيع استخدام التطبيق. ير...
#
#      different from msa from 1 to 3                     intent  \
# 0                                 3  general_positive_feedback
# 1                                 2                     oodoos
# 2                                 2               cancel_order
# 3                                 1           compromised_card
# 4                                 3                 get_refund
# ..                              ...                        ...
# 357                               2   contact_customer_service
# 358                               2                  insurance
# 359                               2               edit_account
# 360                               1  general_negative_feedback
# 361                               1       lost_or_stolen_phone
#
#                intent_pred_ara            intent_pred_dar  \
# 0    general_positive_feedback  general_positive_feedback
# 1                       oodoos                     oodoos
# 2                 cancel_order               cancel_order
# 3             compromised_card           compromised_card
# 4                   get_refund                 get_refund
# ..                         ...                        ...
# 357   contact_customer_service   contact_customer_service
# 358                  insurance                  insurance
# 359               edit_account               edit_account
# 360  general_negative_feedback  general_negative_feedback
# 361       lost_or_stolen_phone       lost_or_stolen_phone
#
#      intent_pred_ara_retriever  intent_pred_dar_retriever  \
# 0    general_positive_feedback  general_positive_feedback
# 1                       oodoos                     oodoos
# 2                 cancel_order               cancel_order
# 3             compromised_card             delete_account
# 4                   get_refund                 get_refund
# ..                         ...                        ...
# 357   contact_customer_service   contact_customer_service
# 358                  insurance                  insurance
# 359               edit_account               edit_account
# 360               edit_account  general_negative_feedback
# 361           compromised_card           compromised_card
#
#        intent_pred_dar_chatgpt
# 0    general_positive_feedback
# 1                       oodoos
# 2                 cancel_order
# 3             compromised_card
# 4                       oodoos
# ..                         ...
# 357        contact_human_agent
# 358                  insurance
# 359               edit_account
# 360        contact_human_agent
# 361       lost_or_stolen_phone
#
# [362 rows x 9 columns]

# %%
# Iterate through each level of differences (0, 1, 2, 4) and filter by indices
for level in [1, 2, 3]:
    print(f"\nMetrics for Darija texts where difference level is {level}:")
    sub_df = df[df["different from msa from 1 to 3"] == level]
    sub_ground_truths = sub_df['intent'].tolist()
    sub_intent_pred_dar = sub_df['intent_pred_dar_chatgpt'].tolist()
    #acc_msa, prec_msa, rec_msa, f1_msa = compute_metrics(sub_ground_truths, sub_intent_pred_ara)
    acc_dar, prec_dar, rec_dar, f1_dar = compute_metrics(sub_ground_truths, sub_intent_pred_dar)
    #print(acc_msa, prec_msa, rec_msa, f1_msa)
    print(acc_dar, prec_dar, rec_dar, f1_dar)
    print('-----------')
# Out:
# Metrics for Darija texts where difference level is 1:
# 0.8181818181818182 0.7877846790890269 0.7355072463768116 0.7402346445824708
# -----------
#
# Metrics for Darija texts where difference level is 2:
# 0.8164794007490637 0.8650980392156863 0.778271345613451 0.79458270454029
# -----------
#
# Metrics for Darija texts where difference level is 3:
# 0.6551724137931034 0.7 0.5833333333333334 0.6076190476190476
# -----------
